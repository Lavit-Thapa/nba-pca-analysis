# %% [markdown]
# ### **Importing the required packages**

# %%
import numpy as np
import pandas  as pd

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA

# %% [markdown]
# ### **Reading and Exploring the Data**

# %%
df = pd.read_csv('/content/nba_final.csv')

# %%
df.head()
# Out:
#     Rk         Player.x  Player_ID Pos1 Pos2  ...  PRank Mvot  MRank  Score  Play
# 0  170     A.J. Hammons  hammoaj01    C  NaN  ...    NaN  NaN    NaN   83.5    No
# 1   58     Aaron Brooks  brookaa01   PG  NaN  ...    NaN  NaN    NaN   48.2    No
# 2  157     Aaron Gordon  gordoaa01   SF  NaN  ...    NaN  NaN    NaN   40.0    No
# 3  352    Adreian Payne  paynead01   PF  NaN  ...   52.0  NaN    NaN   75.5    No
# 4   10  Al-Farouq Aminu  aminual01   PF  NaN  ...   23.0  NaN    NaN   42.8    No
#
# [5 rows x 45 columns]

# %%
df.shape
# Out:
# (1408, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1408 entries, 0 to 1407
# Data columns (total 45 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rk          1408 non-null   int64
#  1   Player.x    1408 non-null   object
#  2   Player_ID   1408 non-null   object
#  3   Pos1        1408 non-null   object
#  4   Pos2        12 non-null     object
#  5   Age         1408 non-null   int64
#  6   Tm          1408 non-null   object
#  7   G           1408 non-null   int64
#  8   GS          1408 non-null   int64
#  9   MP          1408 non-null   float64
#  10  FG          1408 non-null   float64
#  11  FGA         1408 non-null   float64
#  12  FG.         1404 non-null   float64
#  13  X3P         1408 non-null   float64
#  14  X3PA        1408 non-null   float64
#  15  X3P.        1309 non-null   float64
#  16  X2P         1408 non-null   float64
#  17  X2PA        1408 non-null   float64
#  18  X2P.        1393 non-null   float64
#  19  eFG.        1404 non-null   float64
#  20  FT          1408 non-null   float64
#  21  FTA         1408 non-null   float64
#  22  FT.         1361 non-null   float64
#  23  ORB         1408 non-null   float64
#  24  DRB         1408 non-null   float64
#  25  TRB         1408 non-null   float64
#  26  AST         1408 non-null   float64
#  27  STL         1408 non-null   float64
#  28  BLK         1408 non-null   float64
#  29  TOV         1408 non-null   float64
#  30  PF          1408 non-null   float64
#  31  PTS         1408 non-null   float64
#  32  Salary      1346 non-null   float64
#  33  mean_views  1270 non-null   float64
#  34  Season      1408 non-null   object
#  35  Conference  1408 non-null   object
#  36  Role        1408 non-null   object
#  37  Fvot        1408 non-null   int64
#  38  FRank       1408 non-null   int64
#  39  Pvot        1249 non-null   float64
#  40  PRank       1249 non-null   float64
#  41  Mvot        1004 non-null   float64
#  42  MRank       1004 non-null   float64
#  43  Score       1408 non-null   float64
#  44  Play        1408 non-null   object
# dtypes: float64(30), int64(6), object(9)
# memory usage: 495.1+ KB

# %%
# If there was a misclassified datatype
# df[''] = df[''].astype(dtype)

# %%
df.isnull().sum() # print the total number of missing values columns-wise
# Out:
# Rk               0
# Player.x         0
# Player_ID        0
# Pos1             0
# Pos2          1396
# Age              0
# Tm               0
# G                0
# GS               0
# MP               0
# FG               0
# FGA              0
# FG.              4
# X3P              0
# X3PA             0
# X3P.            99
# X2P              0
# X2PA             0
# X2P.            15
# eFG.             4
# FT               0
# FTA              0
# FT.             47
# ORB              0
# DRB              0
# TRB              0
# AST              0
# STL              0
# BLK              0
# TOV              0
# PF               0
# PTS              0
# Salary          62
# mean_views     138
# Season           0
# Conference       0
# Role             0
# Fvot             0
# FRank            0
# Pvot           159
# PRank          159
# Mvot           404
# MRank          404
# Score            0
# Play             0
# dtype: int64

# %%
df.isnull().sum(axis=1) # print the total number of missing values row-wise
# Out:
# 0       6
# 1       5
# 2       5
# 3       3
# 4       3
#        ..
# 1403    1
# 1404    1
# 1405    4
# 1406    1
# 1407    1
# Length: 1408, dtype: int64

# %%
df[df.isnull().sum(axis=1) > 6]
# Out:
#        Rk       Player.x  Player_ID Pos1 Pos2  ...  PRank Mvot  MRank  Score  Play
# 27    341  Arinze Onuaku  onuakar01    C  NaN  ...    NaN  NaN    NaN   90.0    No
# 78    235   Damian Jones  jonesda03    C  NaN  ...    NaN  NaN    NaN   45.0    No
# 86    204   Danuel House  houseda01   SG  NaN  ...   40.0  NaN    NaN   73.5    No
# 169   360    Jakob Pöltl  poeltja01    C  NaN  ...    NaN  NaN    NaN   62.0    No
# 472   348      Ben Moore  moorebe01   PF  NaN  ...   74.0  0.0    8.0  158.5    No
# 904   307    Tyler Lydon  lydonty01   PF  NaN  ...   47.0  0.0    9.0  118.2    No
# 1089  282    George King   kingge03   SF  NaN  ...   84.0  0.0    8.0  152.0    No
#
# [7 rows x 45 columns]

# %%
df = df[df.isnull().sum(axis=1) <= 6]
# alternate method of running the above condition
# df = df[~(df.isnull().sum(axis=1) >6)]

# %%
df['Pos2']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1403    NaN
# 1404    NaN
# 1405    NaN
# 1406    NaN
# 1407    NaN
# Name: Pos2, Length: 1401, dtype: object

# %%
df['Pos2'] = df['Pos2'].fillna('None')

# %%
df.isnull().sum()
# Out:
# Rk              0
# Player.x        0
# Player_ID       0
# Pos1            0
# Pos2            0
# Age             0
# Tm              0
# G               0
# GS              0
# MP              0
# FG              0
# FGA             0
# FG.             0
# X3P             0
# X3PA            0
# X3P.           92
# X2P             0
# X2PA            0
# X2P.           11
# eFG.            0
# FT              0
# FTA             0
# FT.            42
# ORB             0
# DRB             0
# TRB             0
# AST             0
# STL             0
# BLK             0
# TOV             0
# PF              0
# PTS             0
# Salary         61
# mean_views    132
# Season          0
# Conference      0
# Role            0
# Fvot            0
# FRank           0
# Pvot          156
# PRank         156
# Mvot          400
# MRank         400
# Score           0
# Play            0
# dtype: int64

# %%
df.isnull().mean()*100 # Percentage of missing values
# Out:
# Rk             0.000000
# Player.x       0.000000
# Player_ID      0.000000
# Pos1           0.000000
# Pos2           0.000000
# Age            0.000000
# Tm             0.000000
# G              0.000000
# GS             0.000000
# MP             0.000000
# FG             0.000000
# FGA            0.000000
# FG.            0.000000
# X3P            0.000000
# X3PA           0.000000
# X3P.           6.566738
# X2P            0.000000
# X2PA           0.000000
# X2P.           0.785153
# eFG.           0.000000
# FT             0.000000
# FTA            0.000000
# FT.            2.997859
# ORB            0.000000
# DRB            0.000000
# TRB            0.000000
# AST            0.000000
# STL            0.000000
# BLK            0.000000
# TOV            0.000000
# PF             0.000000
# PTS            0.000000
# Salary         4.354033
# mean_views     9.421842
# Season         0.000000
# Conference     0.000000
# Role           0.000000
# Fvot           0.000000
# FRank          0.000000
# Pvot          11.134904
# PRank         11.134904
# Mvot          28.551035
# MRank         28.551035
# Score          0.000000
# Play           0.000000
# dtype: float64

# %%
df['Salary']
# Out:
# 0              NaN
# 1        2700000.0
# 2        4351320.0
# 3        2022240.0
# 4        7680965.0
#            ...
# 1403     3628920.0
# 1404    19500000.0
# 1405       77250.0
# 1406     2393887.0
# 1407     2615160.0
# Name: Salary, Length: 1401, dtype: float64

# %%
df = df.fillna(0)

# %% [markdown]
# ### **Check for Duplicates**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace =True) # drop all the duplicate rows

# %%
# df.drop_duplicates(subset=['Pos2', 'Role', 'Pvot'])

# %%
df.drop(columns=['Player.x','Player_ID'], inplace=True)

# %% [markdown]
# ### **Encode the Categorical columns values**

# %%
obj_cols = df.select_dtypes('object').columns

# %%
le = LabelEncoder()

for  col in obj_cols:
  df[col] = le.fit_transform(df[col])

# %%
df['Play'].value_counts()
# Out:
# Play
# 0    1328
# 1      73
# Name: count, dtype: int64

# %% [markdown]
# ### **Machine Learning Process**

# %%
X = df.drop(columns= 'Play')
y = df['Play']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2,stratify=y , random_state=34)

# %% [markdown]
# ### **Standardization**

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### **Apply Logistic Regression on the data**

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_reg.predict(X_test_scaled)

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 98.57651245551602

# %%
roc_auc_score(y_test, y_pred)*100
# Out:
# np.float64(86.66666666666667)

# %% [markdown]
# ### **Now Let's transfom the data using PCA**

# %%
pca = PCA(n_components=0.95)

# %%
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
X_train_pca.shape
# Out:
# (1120, 22)

# %%
pd.DataFrame(X_train_pca)
# Out:
#             0         1         2   ...        19        20        21
# 0     1.743592 -2.962779  1.275286  ...  0.604208  0.229382 -0.698032
# 1    -1.720394  2.632226 -0.588966  ... -0.011686  1.370912  0.109538
# 2    -3.207607  2.427227  0.771961  ...  0.525933 -0.036536  0.909073
# 3    -1.095497 -1.300507  0.204654  ...  0.441277 -0.807869  0.434454
# 4     2.829147 -3.748800  0.595624  ... -0.057565 -0.065620 -0.369492
# ...        ...       ...       ...  ...       ...       ...       ...
# 1115  2.059740  1.001131 -0.322681  ...  1.383374  0.012538 -0.466676
# 1116 -4.724008  1.657865  1.915426  ... -0.181213  0.245849 -0.353612
# 1117 -2.272954  0.716595 -0.974287  ...  0.432826  0.368559  0.927371
# 1118 -1.392386 -0.351281 -1.686259  ...  0.523921  0.630223  0.780769
# 1119 -4.247488  2.358699  0.984842  ... -0.056258  0.703164  0.065127
#
# [1120 rows x 22 columns]

# %% [markdown]
# ### **Applying Logistic Regression on the PCA transformed Data**

# %%
log_reg2 = LogisticRegression()
log_reg2.fit(X_train_pca, y_train)
# Out:
# LogisticRegression()

# %%
y_pred2 = log_reg2.predict(X_test_pca)

# %%
roc_auc_score(y_test, y_pred2)*100
# Out:
# np.float64(80.0)
